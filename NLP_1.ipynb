# %% [markdown]
# <a href="https://colab.research.google.com/github/ochekroun/labs/blob/master/NLP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls -la
# Out:
# total 20436
# drwxr-xr-x 1 root root     4096 May 14 17:18 .
# drwxr-xr-x 1 root root     4096 May 14 17:09 ..
# -rw-r--r-- 1 root root 18812026 May 14 17:18 archive.zip
# drwxr-xr-x 4 root root     4096 May 14 09:18 .config
# -rw-r--r-- 1 root root  2097152 May 14 17:18 prenoms.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('prenoms.csv')
df['name'] = df['name'].str.lower()
df = df.groupby('name', as_index=False).agg({'count': 'sum'})
df = df [df['count'] >= 50]
df = df.sample(frac=1.0)
df = df[:100]
df
#df.sort_values(by='count', ascending = False)
# Out:
#                name  count
# 18932  marie-audrey    146
# 1296       allissia     86
# 28319       sylvine   1261
# 14822         kerim    927
# 1225         alison  15793
# ...             ...    ...
# 20085       maëllia    101
# 25960        salama    131
# 23409       omerine    240
# 29150         tiano    101
# 11446          hina    522
#
# [100 rows x 2 columns]
